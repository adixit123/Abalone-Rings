# %%
import pandas as pd
import numpy as np
train=pd.read_csv("train.csv")

test=pd.read_csv("test.csv")
trainSex=train["Sex"]
testSex=test["Sex"]
train=train.drop(["Sex"],axis=1)
test=test.drop(["Sex"],axis=1)
train
# Out:
#           id  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0          0   0.550     0.430   0.150        0.7715          0.3285
# 1          1   0.630     0.490   0.145        1.1300          0.4580
# 2          2   0.160     0.110   0.025        0.0210          0.0055
# 3          3   0.595     0.475   0.150        0.9145          0.3755
# 4          4   0.555     0.425   0.130        0.7820          0.3695
# ...      ...     ...       ...     ...           ...             ...
# 90610  90610   0.335     0.235   0.075        0.1585          0.0685
# 90611  90611   0.555     0.425   0.150        0.8790          0.3865
# 90612  90612   0.435     0.330   0.095        0.3215          0.1510
# 90613  90613   0.345     0.270   0.075        0.2000          0.0980
# 90614  90614   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight  Rings
# 0              0.1465        0.2400     11
# 1              0.2765        0.3200     11
# 2              0.0030        0.0050      6
# 3              0.2055        0.2500     10
# 4              0.1600        0.1975      9
# ...               ...           ...    ...
# 90610          0.0370        0.0450      6
# 90611          0.1815        0.2400      9
# 90612          0.0785        0.0815      6
# 90613          0.0490        0.0700      6
# 90614          0.0785        0.1050      8
#
# [90615 rows x 9 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
Encoder=OrdinalEncoder()

train=pd.concat([train,pd.DataFrame(Encoder.fit_transform(trainSex.values.reshape(-1,1)),columns=["Sex"])],axis=1)
test=pd.concat([test,pd.DataFrame(Encoder.fit_transform(testSex.values.reshape(-1,1)),columns=["Sex"])],axis=1)

# %%
train
# Out:
#           id  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0          0   0.550     0.430   0.150        0.7715          0.3285
# 1          1   0.630     0.490   0.145        1.1300          0.4580
# 2          2   0.160     0.110   0.025        0.0210          0.0055
# 3          3   0.595     0.475   0.150        0.9145          0.3755
# 4          4   0.555     0.425   0.130        0.7820          0.3695
# ...      ...     ...       ...     ...           ...             ...
# 90610  90610   0.335     0.235   0.075        0.1585          0.0685
# 90611  90611   0.555     0.425   0.150        0.8790          0.3865
# 90612  90612   0.435     0.330   0.095        0.3215          0.1510
# 90613  90613   0.345     0.270   0.075        0.2000          0.0980
# 90614  90614   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight  Rings  Sex
# 0              0.1465        0.2400     11  0.0
# 1              0.2765        0.3200     11  0.0
# 2              0.0030        0.0050      6  1.0
# 3              0.2055        0.2500     10  2.0
# 4              0.1600        0.1975      9  1.0
# ...               ...           ...    ...  ...
# 90610          0.0370        0.0450      6  2.0
# 90611          0.1815        0.2400      9  2.0
# 90612          0.0785        0.0815      6  1.0
# 90613          0.0490        0.0700      6  1.0
# 90614          0.0785        0.1050      8  1.0
#
# [90615 rows x 10 columns]

# %%
test
# Out:
#            id  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0       90615   0.645     0.475   0.155        1.2380          0.6185
# 1       90616   0.580     0.460   0.160        0.9830          0.4785
# 2       90617   0.560     0.420   0.140        0.8395          0.3525
# 3       90618   0.570     0.490   0.145        0.8740          0.3525
# 4       90619   0.415     0.325   0.110        0.3580          0.1575
# ...       ...     ...       ...     ...           ...             ...
# 60406  151021   0.345     0.260   0.085        0.1775          0.0735
# 60407  151022   0.525     0.410   0.145        0.8445          0.3885
# 60408  151023   0.590     0.440   0.155        1.1220          0.3930
# 60409  151024   0.660     0.525   0.190        1.4935          0.5885
# 60410  151025   0.430     0.340   0.120        0.4150          0.1525
#
#        Whole weight.2  Shell weight  Sex
# 0              0.3125        0.3005  2.0
# 1              0.2195        0.2750  2.0
# 2              0.1845        0.2405  2.0
# 3              0.1865        0.2350  2.0
# 4              0.0670        0.1050  1.0
# ...               ...           ...  ...
# 60406          0.0265        0.0500  1.0
# 60407          0.1670        0.2050  0.0
# 60408          0.2000        0.2650  1.0
# 60409          0.3575        0.4350  0.0
# 60410          0.0910        0.0905  0.0
#
# [60411 rows x 9 columns]

# %%
train.corr()
# Out:
#                       id    Length  Diameter    Height  Whole weight  \
# id              1.000000  0.004724  0.004290  0.005916      0.005228
# Length          0.004724  1.000000  0.989732  0.916094      0.931449
# Diameter        0.004290  0.989732  1.000000  0.919618      0.933848
# Height          0.005916  0.916094  0.919618  1.000000      0.902344
# Whole weight    0.005228  0.931449  0.933848  0.902344      1.000000
# Whole weight.1  0.004203  0.909609  0.908466  0.861769      0.971249
# Whole weight.2  0.004878  0.913134  0.914668  0.886132      0.974319
# Shell weight    0.005887  0.911073  0.917871  0.904019      0.964201
# Rings           0.000938  0.623786  0.636832  0.665772      0.617274
# Sex            -0.003553 -0.020774 -0.021648 -0.029732     -0.027787
#
#                 Whole weight.1  Whole weight.2  Shell weight     Rings  \
# id                    0.004203        0.004878      0.005887  0.000938
# Length                0.909609        0.913134      0.911073  0.623786
# Diameter              0.908466        0.914668      0.917871  0.636832
# Height                0.861769        0.886132      0.904019  0.665772
# Whole weight          0.971249        0.974319      0.964201  0.617274
# Whole weight.1        1.000000        0.949227      0.911800  0.515067
# Whole weight.2        0.949227        1.000000      0.937069  0.588954
# Shell weight          0.911800        0.937069      1.000000  0.694766
# Rings                 0.515067        0.588954      0.694766  1.000000
# Sex                  -0.017512       -0.032769     -0.033301 -0.026308
#
#                      Sex
# id             -0.003553
# Length         -0.020774
# Diameter       -0.021648
# Height         -0.029732
# Whole weight   -0.027787
# Whole weight.1 -0.017512
# Whole weight.2 -0.032769
# Shell weight   -0.033301
# Rings          -0.026308
# Sex             1.000000

# %%
train.corr()
# Out:
#                       id    Length  Diameter    Height  Whole weight  \
# id              1.000000  0.004724  0.004290  0.005916      0.005228
# Length          0.004724  1.000000  0.989732  0.916094      0.931449
# Diameter        0.004290  0.989732  1.000000  0.919618      0.933848
# Height          0.005916  0.916094  0.919618  1.000000      0.902344
# Whole weight    0.005228  0.931449  0.933848  0.902344      1.000000
# Whole weight.1  0.004203  0.909609  0.908466  0.861769      0.971249
# Whole weight.2  0.004878  0.913134  0.914668  0.886132      0.974319
# Shell weight    0.005887  0.911073  0.917871  0.904019      0.964201
# Rings           0.000938  0.623786  0.636832  0.665772      0.617274
# Sex            -0.003553 -0.020774 -0.021648 -0.029732     -0.027787
#
#                 Whole weight.1  Whole weight.2  Shell weight     Rings  \
# id                    0.004203        0.004878      0.005887  0.000938
# Length                0.909609        0.913134      0.911073  0.623786
# Diameter              0.908466        0.914668      0.917871  0.636832
# Height                0.861769        0.886132      0.904019  0.665772
# Whole weight          0.971249        0.974319      0.964201  0.617274
# Whole weight.1        1.000000        0.949227      0.911800  0.515067
# Whole weight.2        0.949227        1.000000      0.937069  0.588954
# Shell weight          0.911800        0.937069      1.000000  0.694766
# Rings                 0.515067        0.588954      0.694766  1.000000
# Sex                  -0.017512       -0.032769     -0.033301 -0.026308
#
#                      Sex
# id             -0.003553
# Length         -0.020774
# Diameter       -0.021648
# Height         -0.029732
# Whole weight   -0.027787
# Whole weight.1 -0.017512
# Whole weight.2 -0.032769
# Shell weight   -0.033301
# Rings          -0.026308
# Sex             1.000000

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
scatter_matrix(train,figsize=(20,12))
plt.show()

# %%
traineng=train
traineng=traineng.drop(["Whole weight","Whole weight.1","Whole weight.2","Shell weight"],axis=1)
testeng=test
testeng=testeng.drop(["Whole weight","Whole weight.1","Whole weight.2","Shell weight"],axis=1)

# %%
traineng["Weight"]=np.log(train["Whole weight"]+train["Whole weight.1"])+(train["Whole weight.2"]+train["Shell weight"])
testeng["Weight"]=np.log(test["Whole weight"]+test["Whole weight.1"])+(test["Whole weight.2"]+test["Shell weight"])

# %%
traineng
# Out:
#           id  Length  Diameter  Height  Rings  Sex    Weight
# 0          0   0.550     0.430   0.150     11  0.0  0.481810
# 1          1   0.630     0.490   0.145     11  0.0  1.058975
# 2          2   0.160     0.110   0.025      6  1.0 -3.622611
# 3          3   0.595     0.475   0.150     10  2.0  0.710142
# 4          4   0.555     0.425   0.130      9  1.0  0.498565
# ...      ...     ...       ...     ...    ...  ...       ...
# 90610  90610   0.335     0.235   0.075      6  2.0 -1.400805
# 90611  90611   0.555     0.425   0.150      9  2.0  0.656967
# 90612  90612   0.435     0.330   0.095      6  1.0 -0.589718
# 90613  90613   0.345     0.270   0.075      6  1.0 -1.091662
# 90614  90614   0.425     0.325   0.100      8  1.0 -0.513655
#
# [90615 rows x 7 columns]

# %%
scatter_matrix(traineng[["Weight","Rings"]],figsize=(12,8))
plt.show()

# %%
traineng.corr()
# Out:
#                 id    Length  Diameter    Height     Rings       Sex    Weight
# id        1.000000  0.004724  0.004290  0.005916  0.000938 -0.003553  0.003897
# Length    0.004724  1.000000  0.989732  0.916094  0.623786 -0.020774  0.982864
# Diameter  0.004290  0.989732  1.000000  0.919618  0.636832 -0.021648  0.981775
# Height    0.005916  0.916094  0.919618  1.000000  0.665772 -0.029732  0.923145
# Rings     0.000938  0.623786  0.636832  0.665772  1.000000 -0.026308  0.643913
# Sex      -0.003553 -0.020774 -0.021648 -0.029732 -0.026308  1.000000 -0.020138
# Weight    0.003897  0.982864  0.981775  0.923145  0.643913 -0.020138  1.000000

# %%
traineng["Dimensions"]=traineng["Length"]*traineng["Diameter"]+traineng["Height"]
testeng["Dimensions"]=testeng["Length"]*testeng["Diameter"]+testeng["Height"]
traineng.corr()
# Out:
#                   id    Length  Diameter    Height     Rings       Sex  \
# id          1.000000  0.004724  0.004290  0.005916  0.000938 -0.003553
# Length      0.004724  1.000000  0.989732  0.916094  0.623786 -0.020774
# Diameter    0.004290  0.989732  1.000000  0.919618  0.636832 -0.021648
# Height      0.005916  0.916094  0.919618  1.000000  0.665772 -0.029732
# Rings       0.000938  0.623786  0.636832  0.665772  1.000000 -0.026308
# Sex        -0.003553 -0.020774 -0.021648 -0.029732 -0.026308  1.000000
# Weight      0.003897  0.982864  0.981775  0.923145  0.643913 -0.020138
# Dimensions  0.005387  0.981170  0.983607  0.957875  0.645751 -0.026843
#
#               Weight  Dimensions
# id          0.003897    0.005387
# Length      0.982864    0.981170
# Diameter    0.981775    0.983607
# Height      0.923145    0.957875
# Rings       0.643913    0.645751
# Sex        -0.020138   -0.026843
# Weight      1.000000    0.966189
# Dimensions  0.966189    1.000000

# %%
scatter_matrix(traineng[["Dimensions","Rings"]],figsize=(12,9))
plt.show()

# %%
traineng=traineng.drop(["Length","Diameter","Height"],axis=1)
testeng=testeng.drop(["Length","Diameter","Height"],axis=1)

# %%
traineng
# Out:
#           id  Rings  Sex    Weight  Dimensions
# 0          0     11  0.0  0.481810    0.386500
# 1          1     11  0.0  1.058975    0.453700
# 2          2      6  1.0 -3.622611    0.042600
# 3          3     10  2.0  0.710142    0.432625
# 4          4      9  1.0  0.498565    0.365875
# ...      ...    ...  ...       ...         ...
# 90610  90610      6  2.0 -1.400805    0.153725
# 90611  90611      9  2.0  0.656967    0.385875
# 90612  90612      6  1.0 -0.589718    0.238550
# 90613  90613      6  1.0 -1.091662    0.168150
# 90614  90614      8  1.0 -0.513655    0.238125
#
# [90615 rows x 5 columns]

# %%
traineng=traineng.drop(["id"],axis=1)
testeng=testeng.drop(["id"],axis=1)
id=test["id"]

# %%
traineng
# Out:
#        Rings  Sex    Weight  Dimensions
# 0         11  0.0  0.481810    0.386500
# 1         11  0.0  1.058975    0.453700
# 2          6  1.0 -3.622611    0.042600
# 3         10  2.0  0.710142    0.432625
# 4          9  1.0  0.498565    0.365875
# ...      ...  ...       ...         ...
# 90610      6  2.0 -1.400805    0.153725
# 90611      9  2.0  0.656967    0.385875
# 90612      6  1.0 -0.589718    0.238550
# 90613      6  1.0 -1.091662    0.168150
# 90614      8  1.0 -0.513655    0.238125
#
# [90615 rows x 4 columns]

# %%
traineng.var()
# Out:
# Rings         10.088379
# Sex            0.632301
# Weight         1.113095
# Dimensions     0.015993
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaledtraincols=pd.DataFrame(scaler.fit_transform(traineng[["Weight","Dimensions"]]),columns=["Weight","Dimensions"])
scaledtestcols=pd.DataFrame(scaler.fit_transform(testeng[["Weight","Dimensions"]]),columns=["Weight","Dimensions"])

# %%
scaledtraincols
# Out:
#          Weight  Dimensions
# 0      0.208771    0.251924
# 1      0.755833    0.783306
# 2     -3.681575   -2.467453
# 3      0.425194    0.616656
# 4      0.224653    0.088833
# ...         ...         ...
# 90610 -1.575652   -1.588736
# 90611  0.374793    0.246982
# 90612 -0.806869   -0.917985
# 90613 -1.282633   -1.474671
# 90614 -0.734774   -0.921346
#
# [90615 rows x 2 columns]

# %%
scaledtraincols.var()
# Out:
# Weight        1.000011
# Dimensions    1.000011
# dtype: float64

# %%
traineng[["Weight","Dimensions"]]=scaledtraincols[["Weight","Dimensions"]]
testeng[["Weight","Dimensions"]]=scaledtestcols[["Weight","Dimensions"]]

# %%
traineng
# Out:
#        Rings  Sex    Weight  Dimensions
# 0         11  0.0  0.208771    0.251924
# 1         11  0.0  0.755833    0.783306
# 2          6  1.0 -3.681575   -2.467453
# 3         10  2.0  0.425194    0.616656
# 4          9  1.0  0.224653    0.088833
# ...      ...  ...       ...         ...
# 90610      6  2.0 -1.575652   -1.588736
# 90611      9  2.0  0.374793    0.246982
# 90612      6  1.0 -0.806869   -0.917985
# 90613      6  1.0 -1.282633   -1.474671
# 90614      8  1.0 -0.734774   -0.921346
#
# [90615 rows x 4 columns]

# %%
testeng
# Out:
#        Sex    Weight  Dimensions
# 0      2.0  0.920825    0.843543
# 1      2.0  0.579966    0.569154
# 2      2.0  0.319526    0.159654
# 3      2.0  0.343377    0.549314
# 4      1.0 -0.720260   -0.874610
# ...    ...       ...         ...
# 60406  1.0 -1.497000   -1.431522
# 60407  0.0  0.301248    0.041011
# 60408  1.0  0.586114    0.472334
# 60409  0.0  1.201089    1.439738
# 60410  0.0 -0.619637   -0.705374
#
# [60411 rows x 3 columns]

# %%
scatter_matrix(traineng,figsize=(20,17))
plt.show()

# %%
from sklearn.model_selection import train_test_split
pretrain,pretest=train_test_split(traineng,test_size=0.2,random_state=42,stratify=traineng["Rings"])

# %%
pretrain
# Out:
#        Rings  Sex    Weight  Dimensions
# 21595      8  0.0  0.490845    0.406120
# 1554      13  2.0  1.102079    1.479558
# 63172     10  0.0  0.747445    0.765119
# 32210     10  1.0  0.230264    0.072030
# 10942     10  2.0  0.784520    1.073510
# ...      ...  ...       ...         ...
# 88132     15  2.0  0.584878    0.051865
# 17540     11  2.0  0.385668    0.590759
# 30598      9  2.0  1.049700    1.070347
# 55258      9  0.0  0.263720    0.087647
# 9965      16  2.0  0.537869    0.485195
#
# [72492 rows x 4 columns]

# %%
xlabels=pretrain["Rings"]
pretrain.drop("Rings",axis=1)
# Out:
#        Sex    Weight  Dimensions
# 21595  0.0  0.490845    0.406120
# 1554   2.0  1.102079    1.479558
# 63172  0.0  0.747445    0.765119
# 32210  1.0  0.230264    0.072030
# 10942  2.0  0.784520    1.073510
# ...    ...       ...         ...
# 88132  2.0  0.584878    0.051865
# 17540  2.0  0.385668    0.590759
# 30598  2.0  1.049700    1.070347
# 55258  0.0  0.263720    0.087647
# 9965   2.0  0.537869    0.485195
#
# [72492 rows x 3 columns]

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
forest=xgb(random_state=0)
parameters = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [1,2,3,4],
}
clf=GridSearchCV(forest,parameters,cv=10,scoring="neg_root_mean_squared_log_error")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 import xgboost as xgb
#       2 from sklearn.model_selection import GridSearchCV
# ----> 3 forest=xgb(random_state=0)
#       4 parameters = {
#       5     'n_estimators': [100, 150, 200, 250, 300],
#       6     'max_depth': [1,2,3,4],
#       7 }
#       8 clf=GridSearchCV(forest,parameters,cv=10,scoring="neg_root_mean_squared_log_error")
#
# TypeError: 'module' object is not callable

# %%
pretrain=pretrain.drop("Rings",axis=1)
clf.fit(pretrain,xlabels)

# %%
ylabels=pretest["Rings"]

# %%
pretest=pretest.drop("Rings",axis=1)

# %%
preresults=pd.DataFrame(clf.predict(pretest),columns=["Rings"])

# %%
preresults

# %%
from sklearn.metrics import mean_squared_log_error as rmlse
rmlse(preresults,ylabels)

# %%
results=pd.DataFrame(clf.predict(testeng),columns=["Rings"])

# %%
finalres=pd.concat([id,results],axis=1)

# %%
finalres

# %%
finalres.to_csv("Results.csv",index=False)
